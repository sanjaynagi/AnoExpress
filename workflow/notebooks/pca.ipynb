# %%
import pandas as pd
import numpy as np
import plotly.express as px
from sklearn.decomposition import PCA

# %%
normCounts.iloc[:,:-1]
# Out:
# GeneID     AGAP000002  AGAP000002  AGAP000005  AGAP000005  AGAP000007  \
# Tie1             1994        1994        3453        3453        1153
# Tie2             2150        2150        3722        3722        1114
# Tie3             1375        1375        2301        2301         824
# Gou1             4048        4048        2884        2884         930
# Gou2             4155        4155        3110        3110         937
# ...               ...         ...         ...         ...         ...
# Dongola2         4182        4182       50036        9193        1495
# Dongola3         2217        2217       25633        4523         702
# Ethiopia1        2056        2056       21132        5286         746
# Ethiopia2        1691        1691       15770        3975         490
# Ethiopia3        1662        1662       24356        4166         721
#
# GeneID     AGAP000008  AGAP000009  AGAP000010  AGAP000011  AGAP000012  ...  \
# ...

# %%
components.shape
# Out:
# (172, 172)

# %%
components[0].shape
# Out:
# (172,)

# %%
np.log2(normCounts.T.iloc[:-1,].astype(float).values)
# Out:
# /home/sanj/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: RuntimeWarning:
#
# divide by zero encountered in log2
# array([[10.96144969, 11.07012094, 10.4252159 , ..., 11.00562455,
#         10.72366094, 10.69870467],
#        [10.96144969, 11.07012094, 10.4252159 , ..., 11.00562455,
#         10.72366094, 10.69870467],
#        [11.75363462, 11.86186234, 11.16804527, ..., 14.36714169,
#         13.94489504, 14.5719896 ],
#        ...,
#        [ 9.08746284,  9.12412131,  8.70390357, ...,  9.28308835,
#          9.16741815,  9.21431912],
#        [ 3.70043972,  3.80735492,  3.32192809, ...,  2.        ,
#          1.        ,  2.32192809],
#        [ 3.70043972,  3.80735492,  3.32192809, ...,  2.        ,
#          1.        ,  2.32192809]])

# %%
normCounts = pd.read_csv("../../final_counts.txt", sep="\t")

normCounts = normCounts.set_index("GeneID")
normCounts = normCounts.iloc[:, 8:].copy().drop_duplicates()

normCounts = normCounts[normCounts.sum(axis=1) > 1000]
print(normCounts.shape)

metadata = pd.read_csv("../../config/ALLcoldata.txt", sep="\t")

normCounts = normCounts.T
normCounts.loc[:, 'species'] = metadata.loc[:, 'species'].to_numpy()

pca = PCA()
components = pca.fit_transform(normCounts.T.iloc[:-1,].astype(float).values)
labels = {
    str(i): f"PC {i+1} ({var:.1f}%)"
    for i, var in enumerate(pca.explained_variance_ratio_ * 100)
}

fig = px.scatter_matrix(
    components,
    #data_frame=normCounts,
    labels=labels,
    dimensions=range(4),
    #color=normCounts["species"]
)
fig.update_traces(diagonal_visible=False)
fig.show()
# Out:
# (14539, 172)
# ...

# %%
normCounts = pd.read_csv("../../final_counts.txt", sep="\t")

normCounts = normCounts.set_index("GeneID")
normCounts = normCounts.iloc[:, 8:].copy().drop_duplicates()

#normCounts = normCounts[normCounts.sum(axis=1) > 1000]
print(normCounts.shape)

metadata = pd.read_csv("../../config/ALLcoldata.txt", sep="\t")

normCounts = normCounts.T
normCounts.loc[:, 'species'] = metadata.loc[:, 'species'].to_numpy()

pca = PCA()
components = pca.fit_transform(normCounts.T.iloc[:-1,].astype(float).values)
labels = {
    str(i): f"PC {i+1} ({var:.1f}%)"
    for i, var in enumerate(pca.explained_variance_ratio_ * 100)
}

fig = px.scatter_matrix(
    components,
    #data_frame=normCounts,
    labels=labels,
    dimensions=range(4),
    #color=normCounts["species"]
)
fig.update_traces(diagonal_visible=False)
fig.show()
