# %% [markdown]
# <a href="https://colab.research.google.com/github/sanjaynagi/AnoExpress/blob/main/workflow/notebooks/Utility_functions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install anoexpress -q

# %%
import anoexpress as xpress

# %% [markdown]
# ### AnoExpress utility functions

# %%
# ?xpress.data

# %%
### load fold-change data
fc_data = xpress.data(data_type='fcs', analysis='gamb_colu_arab_fun', microarray=False)
fc_data.head()
# Out:
#                      Tiefora_v_Ngousso  Gou_v_Moz  Ban_v_BanS  BanRe_v_BanS  \
# GeneID     GeneName
# AGAP007364 NaN                   -2.61      -0.14       -1.02          1.32
# AGAP010071 NaN                   -2.32       0.31       -2.30         -0.37
# AGAP007774 NaN                   -1.77      -0.61       -0.93         -0.20
# AGAP005809 NaN                   -2.01      -0.18       -1.80          0.10
# AGAP006191 Cht24                  3.89      -1.91        2.37          0.69
#
#                      Bak_v_Kisumu  VK7_v_Kisumu  Cameroon_v_Ngousso  \
# GeneID     GeneName
# AGAP007364 NaN               0.42          0.89               -1.03
# AGAP010071 NaN              -0.36         -0.59               -1.86
# AGAP007774 NaN              -0.17         -0.46               -0.11
# AGAP005809 NaN              -1.06         -1.50               -0.46
# AGAP006191 Cht24            -1.38          1.94                5.46
#
# ...

# %%
### load pval data
pvals_data = xpress.data(data_type='pvals', analysis='gamb_colu_arab_fun', microarray=False)
pvals_data.head()
# Out:
#             Tiefora_v_Ngousso  Gou_v_Moz  Ban_v_BanS  BanRe_v_BanS  \
# GeneID
# AGAP007364                0.0      0.719       0.003         0.000
# AGAP010071                0.0      0.212       0.000         0.147
# AGAP007774                0.0      0.000       0.000         0.337
# AGAP005809                0.0      0.313       0.000         0.577
# AGAP006191                0.0      0.019       0.001         0.397
#
#             Bak_v_Kisumu  VK7_v_Kisumu  Cameroon_v_Ngousso  Chad_v_Ngousso  \
# GeneID
# AGAP007364         0.028         0.009               0.000           0.786
# AGAP010071         0.001         0.000               0.000           0.000
# AGAP007774         0.243         0.000               0.734           0.886
# AGAP005809         0.000         0.000               0.094           0.282
# AGAP006191         0.000         0.000               0.000           0.000
#
#             Niger_v_Ngousso  Nigeria_v_Ngousso  ...  Ghana_fun_v_Fang  \
# ...

# %%
## load fold-change data including ir-tex data
fc_data = xpress.data(data_type='fcs', analysis='gamb_colu_arab_fun', microarray=True)
fc_data.head()
# Out:
#                      Tiefora_v_Ngousso  Gou_v_Moz  Ban_v_BanS  BanRe_v_BanS  \
# GeneID     GeneName
# AGAP007364 NaN                   -2.61      -0.14       -1.02          1.32
# AGAP010071 NaN                   -2.32       0.31       -2.30         -0.37
# AGAP007774 NaN                   -1.77      -0.61       -0.93         -0.20
# AGAP005809 NaN                   -2.01      -0.18       -1.80          0.10
# AGAP006191 Cht24                  3.89      -1.91        2.37          0.69
#
#                      Bak_v_Kisumu  VK7_v_Kisumu  Cameroon_v_Ngousso  \
# GeneID     GeneName
# AGAP007364 NaN               0.42          0.89               -1.03
# AGAP010071 NaN              -0.36         -0.59               -1.86
# AGAP007774 NaN              -0.17         -0.46               -0.11
# AGAP005809 NaN              -1.06         -1.50               -0.46
# AGAP006191 Cht24            -1.38          1.94                5.46
#
# ...

# %%
## load metadata
comparisons_df = xpress.metadata(analysis='gamb_colu_arab_fun', microarray=True)
comparisons_df
# Out:
#                      comparison          resistant susceptible     species  \
# 0             Tiefora_v_Ngousso            Tiefora     Ngousso    coluzzii
# 1                     Gou_v_Moz                Gou         Moz  arabiensis
# 2                    Ban_v_BanS                Ban        BanS    coluzzii
# 3                  BanRe_v_BanS              BanRe        BanS    coluzzii
# 4                  Bak_v_Kisumu                Bak      Kisumu     gambiae
# 5                  VK7_v_Kisumu                VK7      Kisumu    coluzzii
# 6            Cameroon_v_Ngousso           Cameroon     Ngousso    coluzzii
# 7                Chad_v_Ngousso               Chad     Ngousso    coluzzii
# 8               Niger_v_Ngousso              Niger     Ngousso    coluzzii
# 9             Nigeria_v_Ngousso            Nigeria     Ngousso    coluzzii
# 10             Agboville_v_Mali          Agboville        Mali    coluzzii
# ...
