# %% [markdown]
# <a href="https://colab.research.google.com/github/sanjaynagi/rna-seq-meta/blob/main/workflow/notebooks/plot-families-expression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import plotly.express as px

def plot_gene_family_fcs(analysis, gene_identifier, title, plot_type='strip', sort_by='median', width=1000, height=None):
  """
  plots fold changes of genes belonging to GO term or pfam protein domain
  """
  # Read in .csv file containing pfam and go terms
  pfam_df = pd.read_csv("https://github.com/sanjaynagi/rna-seq-meta/blob/main/resources/Anogam_long.pep_Pfamscan.seqs.gz?raw=true", sep="\s+", header=None, compression='gzip')
  go_df = pd.read_csv("https://github.com/sanjaynagi/rna-seq-meta/blob/main/resources/Anogam_long.pep_eggnog_diamond.emapper.annotations.GO.gz?raw=true", sep="\t", header=None, compression='gzip')
  pfam_df.columns = ["transcript", "pstart", "pend", "pfamid", "domain", "domseq"]
  go_df.columns = ['transcript', 'GO_terms']

  gene_annot_df = pfam_df.merge(go_df)
  gene_annot_df.loc[:, 'gene_id'] = gene_annot_df.loc[:, 'transcript'].str.replace("Anogam_", "").str.replace("-R[A-Z]", "", regex=True)
  gene_ids = gene_ids_from_annotation(gene_annot_df, gene_identifier)

  # load metadata
  metadata = pd.read_csv("https://raw.githubusercontent.com/sanjaynagi/rna-seq-meta/main/config/comparison_metadata.tsv", sep="\t")  
  # load fold change data and remove gene description column
  fc_data = pd.read_csv(f"https://raw.githubusercontent.com/sanjaynagi/rna-seq-meta/main/results/fcs.{analysis}.tsv", sep="\t")
  fc_data = fc_data.iloc[:, :-1]

  fam_fc_data = fc_data.query("GeneID in @gene_ids").copy()

  assert not fam_fc_data.empty, "No genes were found for the selection. It is possible these genes were removed by the ortholog finding process"

  if sort_by == 'median':
    sort_idxs = np.argsort(fam_fc_data.set_index(['GeneID', 'GeneName']).apply(np.nanmedian, axis=1)).values
  elif sort_by == 'mean':
    sort_idxs = np.argsort(fam_fc_data.set_index(['GeneID', 'GeneName']).apply(np.nanmean, axis=1)).values
  elif sort_by == 'agap':
    sort_idxs = np.argsort(fam_fc_data['GeneID'].values)[::-1] 
  fam_fc_data = fam_fc_data.iloc[sort_idxs, :]
    
  fam_fc_data.loc[:, 'Label'] = [id_ + " | " + name if name != "" else id_ for id_, name in zip(fam_fc_data['GeneID'].fillna(""), fam_fc_data['GeneName'].fillna(""))]
  fam_fc_data =fam_fc_data.drop(columns=['GeneName', 'GeneID']).melt(id_vars='Label', var_name='comparison', value_name='log2fold_change')
  fam_fc_data.loc[:, 'comparison'] = fam_fc_data['comparison'].str.replace("_log2FoldChange", "")
  fam_fc_data = fam_fc_data.merge(metadata, how='left')
  fam_fc_data.loc[:, 'fold_change'] =  np.round(2**fam_fc_data.loc[:, 'log2fold_change'].values, 2)

  if not height:
    height = np.min([fam_fc_data.shape[0]*5, 2500])
  
  my_plot = px.strip if plot_type == 'strip' else px.box
  fig = my_plot(
      fam_fc_data, 
      y='Label', 
      x='log2fold_change', 
      color='species',
      title=title, 
      hover_data=['fold_change', 'resistant', 'susceptible', 'species', 'country'],
      width=width, 
      height=height,
      template='ggplot2'
  )
  fig.update_layout(titlefont=dict(size=20), xaxis_range=[-4,6],     xaxis_title="log2 Fold Change", yaxis_title="Gene")
  fig.add_vline(0,  line_width=1, line_dash="dash", line_color="grey")
  fig.show()

def gene_ids_from_annotation(gene_annot_df, annotation):
    if isinstance(annotation, list):
        gene_list = np.array([])
        if annotation[0].startswith("GO"):
            for go in annotation:
              ids = gene_annot_df.query(f"GO_terms.str.contains('{go}', na=False)", engine='python')['gene_id'].to_numpy()
              gene_list = np.hstack([gene_list, ids])
            return(np.unique(gene_list))
        else:
          for dom in annotation:
              ids = gene_annot_df.query("domain == @annotation")['gene_id'].to_numpy()
              gene_list = np.hstack([gene_list, ids])
          return(np.unique(gene_list))
    else:
        if annotation.startswith("GO"): 
          return(gene_annot_df.query(f"GO_terms.str.contains('{annotation}', na=False)", engine='python')['gene_id'].to_numpy())
        else:
          return(gene_annot_df.query("domain == @annotation")['gene_id'].to_numpy())

# %% [markdown]
# **Across gene families, pfam domains and GO terms**
#
# In this notebook, we can plot gene expression for all genes assigned a given pfam domain, or GO term. If searching a PFAM domain, the gene identifier should be the 'short_name' PFAM code, not the PFAMID.
#
# If you have ideas for genesets to use or for improvements to the plots, please let me know :)

# %%
plot_gene_family_fcs(analysis='gamb_colu_arab_fun', gene_identifier="Chitin_bind_4", title="chitin binding", plot_type='strip', sort_by='median', height=800)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="45aace49-0a22-4ec9-9d09-a1b442695da3" class="plotly-graph-div" style="height:800px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("45aace49-0a22-4ec9-9d09-a1b442695da3")) {                    Plotly.newPlot(                        "45aace49-0a22-4ec9-9d09-a1b442695da3",                        [{"alignmentgroup":"True","boxpoints":"all","customdata":[[1.48,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[2.77,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[0.17,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[0.37,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[0.22,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[0.35,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[0.54,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[0.26,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[0.55,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[1.4,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[0.43,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[2.83,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[0.65,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[2.77,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[0.2,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[0.23,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[1.92,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[null,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[0.35,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[2.3,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[0.38,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[3.23,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[0.73,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[1.01,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[0.73,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[1.01,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[1.05,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[0.36,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[3.43,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[1.2,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[0.44,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[null,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[0.29,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[5.13,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[2.53,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[null,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[0.72,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[1.11,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[0.82,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[1.4,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[4.06,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[1.02,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[1.39,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[null,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[1.01,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[1.78,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[0.34,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[5.86,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[null,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[1.18,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[2.77,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[7.31,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[null,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[0.77,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[0.44,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[1.58,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[2.85,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[null,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[1.52,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[1.87,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[null,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[2.46,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[2.75,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[null,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[0.31," ...

# %% [markdown]
# **All gene families linked to insecticide resistance**

# %%
# a dict with gene families and their respective Pfam domain for extracting
gene_fams = {'Cytochrome P450s':'p450', 
             'GSTs':['GST_N', 'GST_N_3', 'GST_C'], 
             'Carboxylesterases': 'COesterase', 
             'ABC-transporters':['ABC_membrane', 'ABC_tran'],
             'CSP': 'OS-D',
             'UGTs': 'UDPGT',
             'Odorant binding proteins':'PBP_GOBP', 
             'Olfactory receptors':'7tm_6', 
             'Ionotropic receptors':['Lig_chan','7tm_1'],
             'Gustatory receptors': '7tm_7',
             'Fatty acid synthases':'ketoacyl-synt',
             'FA Elongase':'ELO',
             'FA desaturase':'FA_desaturase',
             'FA reductase':'NAD_binding_4',
             }

for name, domain in gene_fams.items():
    
    plot_gene_family_fcs(analysis='gamb_colu_arab_fun', gene_identifier=domain, title=name, sort_by='median', plot_type='strip')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="4b66d3b0-d842-4f0d-9247-eae69bae51c3" class="plotly-graph-div" style="height:2500px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4b66d3b0-d842-4f0d-9247-eae69bae51c3")) {                    Plotly.newPlot(                        "4b66d3b0-d842-4f0d-9247-eae69bae51c3",                        [{"alignmentgroup":"True","boxpoints":"all","customdata":[[0.33,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[1.08,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[1.44,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[0.34,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[0.38,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[0.68,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[1.12,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[0.82,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[0.87,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[0.23,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[0.8,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[2.38,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[0.33,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[0.45,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[0.53,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[1.41,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[0.85,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[0.92,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[0.97,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[0.15,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[1.19,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[0.84,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[0.46,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[0.59,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[0.99,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[0.62,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[1.67,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[1.42,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[1.13,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[1.27,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[1.13,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[0.92,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[0.84,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[0.78,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[1.41,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[0.96,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[1.39,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[1.13,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[1.07,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[1.12,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[1.69,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[1.24,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[1.29,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[0.43,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[1.23,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[2.25,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[2.35,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[1.85,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[1.72,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[1.0,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[1.57,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[1.16,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[0.98,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[1.03,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[2.79,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[0.85,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[1.24,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[1.44,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[1.03,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[1.62,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[1.43,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[0.73,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[1.01,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[1.06,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[0. ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="d56c4335-0792-49ba-9b24-4c7149f47106" class="plotly-graph-div" style="height:2500px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d56c4335-0792-49ba-9b24-4c7149f47106")) {                    Plotly.newPlot(                        "d56c4335-0792-49ba-9b24-4c7149f47106",                        [{"alignmentgroup":"True","boxpoints":"all","customdata":[[1.1,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[0.94,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[1.33,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[1.33,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[1.48,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[0.72,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[1.04,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[0.94,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[1.16,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[1.23,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[0.97,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[0.95,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[4.03,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[0.69,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[0.99,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[1.09,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[1.27,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[0.8,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[0.83,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[1.11,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[5.31,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[1.87,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[0.73,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[1.19,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[4.14,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[0.18,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[3.56,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[0.66,"Ban","BanS","coluzzii","Burkina Faso"],[0.81,"Ban","BanS","coluzzii","Burkina Faso"],[1.04,"Ban","BanS","coluzzii","Burkina Faso"],[1.03,"Ban","BanS","coluzzii","Burkina Faso"],[1.34,"Ban","BanS","coluzzii","Burkina Faso"],[0.54,"Ban","BanS","coluzzii","Burkina Faso"],[0.87,"Ban","BanS","coluzzii","Burkina Faso"],[0.5,"Ban","BanS","coluzzii","Burkina Faso"],[1.3,"Ban","BanS","coluzzii","Burkina Faso"],[1.08,"Ban","BanS","coluzzii","Burkina Faso"],[0.66,"Ban","BanS","coluzzii","Burkina Faso"],[0.9,"Ban","BanS","coluzzii","Burkina Faso"],[1.21,"Ban","BanS","coluzzii","Burkina Faso"],[0.31,"Ban","BanS","coluzzii","Burkina Faso"],[1.27,"Ban","BanS","coluzzii","Burkina Faso"],[0.71,"Ban","BanS","coluzzii","Burkina Faso"],[0.77,"Ban","BanS","coluzzii","Burkina Faso"],[0.44,"Ban","BanS","coluzzii","Burkina Faso"],[1.13,"Ban","BanS","coluzzii","Burkina Faso"],[1.71,"Ban","BanS","coluzzii","Burkina Faso"],[0.21,"Ban","BanS","coluzzii","Burkina Faso"],[3.36,"Ban","BanS","coluzzii","Burkina Faso"],[0.8,"Ban","BanS","coluzzii","Burkina Faso"],[0.88,"Ban","BanS","coluzzii","Burkina Faso"],[2.71,"Ban","BanS","coluzzii","Burkina Faso"],[44.32,"Ban","BanS","coluzzii","Burkina Faso"],[4.14,"Ban","BanS","coluzzii","Burkina Faso"],[0.82,"BanRe","BanS","coluzzii","Burkina Faso"],[0.54,"BanRe","BanS","coluzzii","Burkina Faso"],[0.93,"BanRe","BanS","coluzzii","Burkina Faso"],[0.82,"BanRe","BanS","coluzzii","Burkina Faso"],[1.02,"BanRe","BanS","coluzzii","Burkina Faso"],[0.95,"BanRe","BanS","coluzzii","Burkina Faso"],[1.06,"BanRe","BanS","coluzzii","Burkina Faso"],[0.69,"BanRe","BanS","coluzzii","Burkina Faso"],[1.54,"BanRe","BanS","coluzzii","Burkina Faso"],[1.1,"BanRe","BanS","coluzzii","Burkina Faso"],[1.21,"BanRe","BanS","coluzzii","Burkina Faso"],[1.28,"BanRe","BanS","coluzzii","Burkina Faso"],[1.16,"BanRe","BanS","coluzzii","Burkina Faso"],[0.59,"BanRe","BanS","coluzzii","Burkina Faso"],[1.22,"BanRe","BanS","coluzzii","Burkina Faso"],[0.95, ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="ca426691-53b6-4bae-bbc5-90669fde9b6d" class="plotly-graph-div" style="height:2500px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ca426691-53b6-4bae-bbc5-90669fde9b6d")) {                    Plotly.newPlot(                        "ca426691-53b6-4bae-bbc5-90669fde9b6d",                        [{"alignmentgroup":"True","boxpoints":"all","customdata":[[1.06,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[0.74,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[0.35,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[0.59,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[0.95,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[1.42,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[0.38,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[1.52,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[0.73,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[2.43,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[1.04,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[0.42,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[0.67,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[2.62,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[0.74,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[1.52,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[1.19,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[1.02,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[0.63,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[0.61,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[1.79,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[0.82,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[1.42,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[null,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[0.37,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[5.86,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[12.55,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[0.8,"Ban","BanS","coluzzii","Burkina Faso"],[0.69,"Ban","BanS","coluzzii","Burkina Faso"],[2.58,"Ban","BanS","coluzzii","Burkina Faso"],[0.36,"Ban","BanS","coluzzii","Burkina Faso"],[0.93,"Ban","BanS","coluzzii","Burkina Faso"],[1.09,"Ban","BanS","coluzzii","Burkina Faso"],[0.51,"Ban","BanS","coluzzii","Burkina Faso"],[0.97,"Ban","BanS","coluzzii","Burkina Faso"],[0.51,"Ban","BanS","coluzzii","Burkina Faso"],[1.16,"Ban","BanS","coluzzii","Burkina Faso"],[0.64,"Ban","BanS","coluzzii","Burkina Faso"],[0.48,"Ban","BanS","coluzzii","Burkina Faso"],[0.57,"Ban","BanS","coluzzii","Burkina Faso"],[1.61,"Ban","BanS","coluzzii","Burkina Faso"],[0.75,"Ban","BanS","coluzzii","Burkina Faso"],[1.21,"Ban","BanS","coluzzii","Burkina Faso"],[1.26,"Ban","BanS","coluzzii","Burkina Faso"],[1.47,"Ban","BanS","coluzzii","Burkina Faso"],[1.04,"Ban","BanS","coluzzii","Burkina Faso"],[1.15,"Ban","BanS","coluzzii","Burkina Faso"],[1.37,"Ban","BanS","coluzzii","Burkina Faso"],[0.15,"Ban","BanS","coluzzii","Burkina Faso"],[0.17,"Ban","BanS","coluzzii","Burkina Faso"],[0.51,"Ban","BanS","coluzzii","Burkina Faso"],[0.23,"Ban","BanS","coluzzii","Burkina Faso"],[5.03,"Ban","BanS","coluzzii","Burkina Faso"],[0.48,"Ban","BanS","coluzzii","Burkina Faso"],[0.76,"BanRe","BanS","coluzzii","Burkina Faso"],[0.97,"BanRe","BanS","coluzzii","Burkina Faso"],[1.43,"BanRe","BanS","coluzzii","Burkina Faso"],[0.52,"BanRe","BanS","coluzzii","Burkina Faso"],[0.49,"BanRe","BanS","coluzzii","Burkina Faso"],[0.57,"BanRe","BanS","coluzzii","Burkina Faso"],[1.26,"BanRe","BanS","coluzzii","Burkina Faso"],[0.68,"BanRe","BanS","coluzzii","Burkina Faso"],[0.77,"BanRe","BanS","coluzzii","Burkina Faso"],[0.38,"BanRe","BanS","coluzzii","Burkina Faso"],[0.99,"BanRe","BanS","coluzzii","Burkina Faso"],[1.66,"BanRe","BanS","coluzzii","Burkina Faso"],[0.72,"BanRe","BanS","coluzzii","Burkina Faso"],[1.01,"BanRe","BanS","coluzzii","Burkina Faso"],[0.93,"BanRe","BanS","coluzzii","Burkina Faso"], ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="b273e40b-448e-49da-b349-b859651f410b" class="plotly-graph-div" style="height:2500px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b273e40b-448e-49da-b349-b859651f410b")) {                    Plotly.newPlot(                        "b273e40b-448e-49da-b349-b859651f410b",                        [{"alignmentgroup":"True","boxpoints":"all","customdata":[[0.88,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[1.47,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[1.17,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[0.71,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[0.71,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[0.81,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[1.72,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[1.23,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[0.49,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[1.0,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[1.13,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[0.99,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[0.92,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[1.12,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[0.85,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[0.82,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[0.73,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[0.86,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[0.98,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[0.82,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[1.82,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[0.84,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[0.83,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[1.11,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[1.29,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[2.04,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[0.64,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[1.1,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[0.57,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[1.06,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[0.82,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[0.7,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[1.37,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[1.47,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[1.52,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[1.02,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[0.82,"Ban","BanS","coluzzii","Burkina Faso"],[0.76,"Ban","BanS","coluzzii","Burkina Faso"],[0.66,"Ban","BanS","coluzzii","Burkina Faso"],[0.74,"Ban","BanS","coluzzii","Burkina Faso"],[0.81,"Ban","BanS","coluzzii","Burkina Faso"],[0.85,"Ban","BanS","coluzzii","Burkina Faso"],[1.28,"Ban","BanS","coluzzii","Burkina Faso"],[0.91,"Ban","BanS","coluzzii","Burkina Faso"],[0.72,"Ban","BanS","coluzzii","Burkina Faso"],[0.85,"Ban","BanS","coluzzii","Burkina Faso"],[0.81,"Ban","BanS","coluzzii","Burkina Faso"],[0.85,"Ban","BanS","coluzzii","Burkina Faso"],[1.16,"Ban","BanS","coluzzii","Burkina Faso"],[1.09,"Ban","BanS","coluzzii","Burkina Faso"],[0.68,"Ban","BanS","coluzzii","Burkina Faso"],[0.91,"Ban","BanS","coluzzii","Burkina Faso"],[0.81,"Ban","BanS","coluzzii","Burkina Faso"],[0.97,"Ban","BanS","coluzzii","Burkina Faso"],[0.95,"Ban","BanS","coluzzii","Burkina Faso"],[1.0,"Ban","BanS","coluzzii","Burkina Faso"],[1.06,"Ban","BanS","coluzzii","Burkina Faso"],[0.99,"Ban","BanS","coluzzii","Burkina Faso"],[0.74,"Ban","BanS","coluzzii","Burkina Faso"],[0.93,"Ban","BanS","coluzzii","Burkina Faso"],[1.03,"Ban","BanS","coluzzii","Burkina Faso"],[1.15,"Ban","BanS","coluzzii","Burkina Faso"],[0.73,"Ban","BanS","coluzzii","Burkina Faso"],[1.04,"Ban","BanS","coluzzii","Burkina Faso"],[0.81,"Ban","BanS","coluzzii","Burkina Faso"],[0.73,"Ban","BanS","coluzzii","Burkina Faso"],[0.79,"Ban","BanS","coluzzii","Burkina Faso"],[0.55,"Ban","BanS","coluzzii","Burkina Faso"],[0.67,"Ban","BanS ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="4e51ca0c-81b3-42fa-886e-7bf33e76ec7e" class="plotly-graph-div" style="height:420px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4e51ca0c-81b3-42fa-886e-7bf33e76ec7e")) {                    Plotly.newPlot(                        "4e51ca0c-81b3-42fa-886e-7bf33e76ec7e",                        [{"alignmentgroup":"True","boxpoints":"all","customdata":[[2.64,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[1.02,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[1.25,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[1.49,"Ban","BanS","coluzzii","Burkina Faso"],[0.95,"Ban","BanS","coluzzii","Burkina Faso"],[1.27,"Ban","BanS","coluzzii","Burkina Faso"],[0.46,"BanRe","BanS","coluzzii","Burkina Faso"],[1.27,"BanRe","BanS","coluzzii","Burkina Faso"],[0.65,"BanRe","BanS","coluzzii","Burkina Faso"],[1.15,"VK7","Kisumu","coluzzii","Burkina Faso"],[0.91,"VK7","Kisumu","coluzzii","Burkina Faso"],[2.36,"VK7","Kisumu","coluzzii","Burkina Faso"],[1.09,"Cameroon","Ngousso","coluzzii","Cameroon"],[0.88,"Cameroon","Ngousso","coluzzii","Cameroon"],[1.27,"Cameroon","Ngousso","coluzzii","Cameroon"],[0.51,"Chad","Ngousso","coluzzii","Chad"],[1.88,"Chad","Ngousso","coluzzii","Chad"],[0.86,"Chad","Ngousso","coluzzii","Chad"],[0.52,"Niger","Ngousso","coluzzii","Niger"],[8.06,"Niger","Ngousso","coluzzii","Niger"],[1.58,"Niger","Ngousso","coluzzii","Niger"],[0.43,"Nigeria","Ngousso","coluzzii","Nigeria"],[4.86,"Nigeria","Ngousso","coluzzii","Nigeria"],[1.95,"Nigeria","Ngousso","coluzzii","Nigeria"],[1.16,"Agboville","Mali","coluzzii","Cote d'Ivoire"],[1.08,"Agboville","Mali","coluzzii","Cote d'Ivoire"],[0.69,"Agboville","Mali","coluzzii","Cote d'Ivoire"],[1.3,"Agboville","Ngousso","coluzzii","Cote d'Ivoire"],[1.42,"Agboville","Ngousso","coluzzii","Cote d'Ivoire"],[0.88,"Agboville","Ngousso","coluzzii","Cote d'Ivoire"],[1.26,"Dabou","Mali","coluzzii","Cote d'Ivoire"],[1.77,"Dabou","Mali","coluzzii","Cote d'Ivoire"],[1.51,"Dabou","Mali","coluzzii","Cote d'Ivoire"],[1.39,"Dabou","Ngousso","coluzzii","Cote d'Ivoire"],[2.31,"Dabou","Ngousso","coluzzii","Cote d'Ivoire"],[1.91,"Dabou","Ngousso","coluzzii","Cote d'Ivoire"],[1.46,"Tiassale","Mali","coluzzii","Cote d'Ivoire"],[1.39,"Tiassale","Mali","coluzzii","Cote d'Ivoire"],[1.82,"Tiassale","Mali","coluzzii","Cote d'Ivoire"],[1.64,"Tiassale","Ngousso","coluzzii","Cote d'Ivoire"],[1.85,"Tiassale","Ngousso","coluzzii","Cote d'Ivoire"],[2.33,"Tiassale","Ngousso","coluzzii","Cote d'Ivoire"],[0.99,"Bouake_colu_unexp","Ngousso","coluzzii","Cote d'Ivoire"],[0.99,"Bouake_colu_unexp","Ngousso","coluzzii","Cote d'Ivoire"],[1.24,"Bouake_colu_unexp","Ngousso","coluzzii","Cote d'Ivoire"]],"fillcolor":"rgba(255,255,255,0)","hoveron":"points","hovertemplate":"species=%{customdata[3]}<br>log2fold_change=%{x}<br>Label=%{y}<br>fold_change=%{customdata[0]}<br>resistant=%{customdata[1]}<br>susceptible=%{customdata[2]}<br>country=%{customdata[4]}<extra></extra>","legendgroup":"coluzzii","line":{"color":"rgba(255,255,255,0)"},"marker":{"color":"#F8766D"},"name":"coluzzii","offsetgroup":"coluzzii","orientation":"h","pointpos":0,"showlegend":true,"x":[1.4,0.03,0.32,0.58,-0.08,0.35,-1.13,0.34,-0.62,0.2,-0.13,1.24,0.13,-0.18,0.35,-0.97,0.91,-0.22,-0.93,3.01,0.66,-1.22,2.28,0.96,0.22,0.11,-0.53,0.38,0.51,-0.18,0.33,0.82,0.59,0.47,1.21,0.93,0.55,0.48,0.86,0.71,0.89,1.22,-0.02,-0.02,0.31],"x0":" ","xaxis":"x","y":["AGAP008062 | CSP4","AGAP008051 | SAP1","AGAP008055 | CSP3","AGAP008062 | CSP4","AGAP008051 | SAP1","AGAP008055 | CSP3","AGAP008062 | CSP4","AGAP008051 | SAP1","AGAP008055 | CSP3","AGAP008062 | CSP4","AGAP008051 | SAP1","AGAP008055 | CSP3","AGAP008062 | CSP4","AGAP008051 | SAP1","AGAP008055 | CSP3","AGAP008062 | CSP4","AGAP008051 | SAP1","AGAP008055 | CSP3","AGAP008062 | CSP4","AGAP00805 ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="d076ec00-7671-47d6-8af9-01117c8eff43" class="plotly-graph-div" style="height:2240px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d076ec00-7671-47d6-8af9-01117c8eff43")) {                    Plotly.newPlot(                        "d076ec00-7671-47d6-8af9-01117c8eff43",                        [{"alignmentgroup":"True","boxpoints":"all","customdata":[[0.33,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[0.77,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[0.99,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[0.75,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[0.77,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[1.06,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[0.84,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[0.82,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[1.16,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[1.04,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[1.82,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[2.07,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[0.13,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[0.74,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[1.13,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[1.68,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[0.15,"Ban","BanS","coluzzii","Burkina Faso"],[1.82,"Ban","BanS","coluzzii","Burkina Faso"],[0.82,"Ban","BanS","coluzzii","Burkina Faso"],[0.86,"Ban","BanS","coluzzii","Burkina Faso"],[2.22,"Ban","BanS","coluzzii","Burkina Faso"],[0.99,"Ban","BanS","coluzzii","Burkina Faso"],[0.67,"Ban","BanS","coluzzii","Burkina Faso"],[1.47,"Ban","BanS","coluzzii","Burkina Faso"],[1.32,"Ban","BanS","coluzzii","Burkina Faso"],[1.36,"Ban","BanS","coluzzii","Burkina Faso"],[1.37,"Ban","BanS","coluzzii","Burkina Faso"],[0.95,"Ban","BanS","coluzzii","Burkina Faso"],[0.72,"Ban","BanS","coluzzii","Burkina Faso"],[0.69,"Ban","BanS","coluzzii","Burkina Faso"],[1.19,"Ban","BanS","coluzzii","Burkina Faso"],[4.5,"Ban","BanS","coluzzii","Burkina Faso"],[0.62,"BanRe","BanS","coluzzii","Burkina Faso"],[1.84,"BanRe","BanS","coluzzii","Burkina Faso"],[1.09,"BanRe","BanS","coluzzii","Burkina Faso"],[0.57,"BanRe","BanS","coluzzii","Burkina Faso"],[1.8,"BanRe","BanS","coluzzii","Burkina Faso"],[0.76,"BanRe","BanS","coluzzii","Burkina Faso"],[0.23,"BanRe","BanS","coluzzii","Burkina Faso"],[0.65,"BanRe","BanS","coluzzii","Burkina Faso"],[1.1,"BanRe","BanS","coluzzii","Burkina Faso"],[1.21,"BanRe","BanS","coluzzii","Burkina Faso"],[1.15,"BanRe","BanS","coluzzii","Burkina Faso"],[0.22,"BanRe","BanS","coluzzii","Burkina Faso"],[1.06,"BanRe","BanS","coluzzii","Burkina Faso"],[1.06,"BanRe","BanS","coluzzii","Burkina Faso"],[1.1,"BanRe","BanS","coluzzii","Burkina Faso"],[1.02,"BanRe","BanS","coluzzii","Burkina Faso"],[0.13,"VK7","Kisumu","coluzzii","Burkina Faso"],[2.91,"VK7","Kisumu","coluzzii","Burkina Faso"],[0.71,"VK7","Kisumu","coluzzii","Burkina Faso"],[0.6,"VK7","Kisumu","coluzzii","Burkina Faso"],[0.57,"VK7","Kisumu","coluzzii","Burkina Faso"],[0.99,"VK7","Kisumu","coluzzii","Burkina Faso"],[2.25,"VK7","Kisumu","coluzzii","Burkina Faso"],[1.96,"VK7","Kisumu","coluzzii","Burkina Faso"],[0.53,"VK7","Kisumu","coluzzii","Burkina Faso"],[2.79,"VK7","Kisumu","coluzzii","Burkina Faso"],[0.88,"VK7","Kisumu","coluzzii","Burkina Faso"],[1.72,"VK7","Kisumu","coluzzii","Burkina Faso"],[1.34,"VK7","Kisumu","coluzzii","Burkina Faso"],[1.13,"VK7","Kisumu","coluzzii","Burkina Faso"],[1.96,"VK7","Kisumu","coluzzii","Burkina Faso"],[3.25,"VK7","Kisumu","coluzzii","Burkina Faso"],[0.06,"Cameroon","Ngousso","coluzzii","Cameroon"],[1.29,"Cameroon","Ngousso","coluzzii","Cameroon"],[0.84,"Cameroon","Ngousso","coluzzii","Cameroon"],[1.13,"Cameroon","Ngousso","coluzzii","Cameroon"],[3.68,"Cameroon","Ngousso","coluzzii","Cameroon"],[1.3,"Cameroon","Ngousso","c ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="dc0ce4e3-b88a-47cc-810b-caa71974cd74" class="plotly-graph-div" style="height:2500px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("dc0ce4e3-b88a-47cc-810b-caa71974cd74")) {                    Plotly.newPlot(                        "dc0ce4e3-b88a-47cc-810b-caa71974cd74",                        [{"alignmentgroup":"True","boxpoints":"all","customdata":[[0.47,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[null,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[5.39,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[1.18,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[1.2,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[0.9,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[0.8,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[0.81,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[1.67,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[1.82,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[1.61,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[1.72,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[0.66,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[0.66,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[0.33,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[0.51,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[0.72,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[1.8,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[1.47,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[2.0,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[0.91,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[5.62,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[0.73,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[null,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[2.16,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[2.85,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[2.11,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[1.17,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[null,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[0.44,"Ban","BanS","coluzzii","Burkina Faso"],[0.83,"Ban","BanS","coluzzii","Burkina Faso"],[0.83,"Ban","BanS","coluzzii","Burkina Faso"],[1.09,"Ban","BanS","coluzzii","Burkina Faso"],[1.45,"Ban","BanS","coluzzii","Burkina Faso"],[0.78,"Ban","BanS","coluzzii","Burkina Faso"],[0.89,"Ban","BanS","coluzzii","Burkina Faso"],[0.66,"Ban","BanS","coluzzii","Burkina Faso"],[1.48,"Ban","BanS","coluzzii","Burkina Faso"],[1.61,"Ban","BanS","coluzzii","Burkina Faso"],[1.53,"Ban","BanS","coluzzii","Burkina Faso"],[2.83,"Ban","BanS","coluzzii","Burkina Faso"],[0.36,"Ban","BanS","coluzzii","Burkina Faso"],[0.68,"Ban","BanS","coluzzii","Burkina Faso"],[0.72,"Ban","BanS","coluzzii","Burkina Faso"],[0.12,"Ban","BanS","coluzzii","Burkina Faso"],[1.91,"Ban","BanS","coluzzii","Burkina Faso"],[1.51,"Ban","BanS","coluzzii","Burkina Faso"],[0.78,"Ban","BanS","coluzzii","Burkina Faso"],[1.73,"Ban","BanS","coluzzii","Burkina Faso"],[0.84,"Ban","BanS","coluzzii","Burkina Faso"],[0.65,"Ban","BanS","coluzzii","Burkina Faso"],[null,"Ban","BanS","coluzzii","Burkina Faso"],[0.8,"Ban","BanS","coluzzii","Burkina Faso"],[1.75,"Ban","BanS","coluzzii","Burkina Faso"],[null,"Ban","BanS","coluzzii","Burkina Faso"],[2.39,"Ban","BanS","coluzzii","Burkina Faso"],[0.97,"Ban","BanS","coluzzii","Burkina Faso"],[null,"Ban","BanS","coluzzii","Burkina Faso"],[0.55,"BanRe","BanS","coluzzii","Burkina Faso"],[0.21,"BanRe","BanS","coluzzii","Burkina Faso"],[1.24,"BanRe","BanS","coluzzii","Burkina Faso"],[0.67,"BanRe","BanS","coluzzii","Burkina Faso"],[0.67,"BanRe","BanS","coluzzii","Burkina Faso"],[1.85,"BanRe","BanS","coluzzii","Burkina Faso"],[1.07,"BanRe","BanS","coluzzii","Burkina Faso"],[1.03,"BanRe","BanS","coluzzii","Burkina Faso"],[0.78,"BanRe","BanS","coluzzii","Burkina Faso"],[0.63,"BanRe","BanS","coluzzii","Burkina Faso"],[0.78,"BanRe","BanS","coluzzii","Burkina Faso"], ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="eac70f46-2e28-4828-95b1-79b006531ea9" class="plotly-graph-div" style="height:2500px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("eac70f46-2e28-4828-95b1-79b006531ea9")) {                    Plotly.newPlot(                        "eac70f46-2e28-4828-95b1-79b006531ea9",                        [{"alignmentgroup":"True","boxpoints":"all","customdata":[[1.42,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[null,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[4.35,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[2.46,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[0.75,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[1.2,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[5.62,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[0.18,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[1.84,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[1.12,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[10.13,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[3.43,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[0.73,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[0.73,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[2.85,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[1.96,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[2.31,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[6.41,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[6.23,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[1.42,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[1.57,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[1.58,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[0.75,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[0.71,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[0.82,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[0.12,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[1.14,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[0.73,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[1.16,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[3.03,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[0.73,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[1.21,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[0.76,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[0.75,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[0.62,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[null,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[1.3,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[4.14,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[3.05,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[4.53,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[22.63,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[1.3,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[0.24,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[3.56,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[2.35,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[1.83,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[1.79,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[5.43,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[1.87,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[1.32,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[1.55,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[32.22,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[4.53,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[0.73,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[null,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[2.77,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[2.77,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[null,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[2.27,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[1.77,"Ban","BanS","coluzzii","Burkina Faso"],[0.36,"Ban","BanS","coluzzii","Burkina Faso"],[0.39,"Ban","BanS","coluzzii","Burkina Faso"],[1.89,"Ban","BanS","coluzzii","Burkina Faso"],[0.35,"Ban","BanS","coluzzii","Burkina Faso"],[1.39,"Ban","BanS","coluzzii","Burki ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="6f42b85d-cc88-4aec-9c6a-981a176dcd79" class="plotly-graph-div" style="height:2500px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6f42b85d-cc88-4aec-9c6a-981a176dcd79")) {                    Plotly.newPlot(                        "6f42b85d-cc88-4aec-9c6a-981a176dcd79",                        [{"alignmentgroup":"True","boxpoints":"all","customdata":[[0.43,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[0.5,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[2.0,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[1.28,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[1.17,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[2.08,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[1.83,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[1.52,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[1.59,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[1.14,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[2.2,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[1.89,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[2.64,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[0.58,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[1.52,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[1.75,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[2.3,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[0.35,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[2.25,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[1.48,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[0.64,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[1.99,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[0.26,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[1.64,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[1.19,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[0.91,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[0.66,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[1.65,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[1.59,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[1.09,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[0.77,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[0.46,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[0.95,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[2.28,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[2.28,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[1.45,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[1.68,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[1.39,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[1.33,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[1.87,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[1.29,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[2.75,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[1.65,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[2.57,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[1.58,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[2.31,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[1.43,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[1.27,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[1.47,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[1.24,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[0.93,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[2.46,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[1.28,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[0.47,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[1.46,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[0.86,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[2.04,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[2.19,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[1.03,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[2.23,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[1.79,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[2.93,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[1.21,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[2.13,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[1.09 ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="d8c81781-01cc-4deb-9b56-4d445b897ef6" class="plotly-graph-div" style="height:2500px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d8c81781-01cc-4deb-9b56-4d445b897ef6")) {                    Plotly.newPlot(                        "d8c81781-01cc-4deb-9b56-4d445b897ef6",                        [{"alignmentgroup":"True","boxpoints":"all","customdata":[[0.4,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[0.75,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[null,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[0.75,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[2.5,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[4.72,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[3.07,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[0.9,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[0.77,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[0.49,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[1.55,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[0.71,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[1.85,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[0.38,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[1.03,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[1.85,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[5.46,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[2.33,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[0.97,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[4.72,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[1.09,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[2.75,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[1.2,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[2.51,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[3.39,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[0.43,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[1.42,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[0.81,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[2.0,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[0.66,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[1.68,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[4.53,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[2.06,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[4.47,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[0.65,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[0.84,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[6.19,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[0.46,"Ban","BanS","coluzzii","Burkina Faso"],[0.26,"Ban","BanS","coluzzii","Burkina Faso"],[1.29,"Ban","BanS","coluzzii","Burkina Faso"],[1.46,"Ban","BanS","coluzzii","Burkina Faso"],[1.2,"Ban","BanS","coluzzii","Burkina Faso"],[1.45,"Ban","BanS","coluzzii","Burkina Faso"],[0.08,"Ban","BanS","coluzzii","Burkina Faso"],[1.21,"Ban","BanS","coluzzii","Burkina Faso"],[0.62,"Ban","BanS","coluzzii","Burkina Faso"],[0.57,"Ban","BanS","coluzzii","Burkina Faso"],[0.31,"Ban","BanS","coluzzii","Burkina Faso"],[0.43,"Ban","BanS","coluzzii","Burkina Faso"],[0.85,"Ban","BanS","coluzzii","Burkina Faso"],[0.27,"Ban","BanS","coluzzii","Burkina Faso"],[0.07,"Ban","BanS","coluzzii","Burkina Faso"],[0.88,"Ban","BanS","coluzzii","Burkina Faso"],[2.35,"Ban","BanS","coluzzii","Burkina Faso"],[1.49,"Ban","BanS","coluzzii","Burkina Faso"],[1.12,"Ban","BanS","coluzzii","Burkina Faso"],[0.3,"Ban","BanS","coluzzii","Burkina Faso"],[0.45,"Ban","BanS","coluzzii","Burkina Faso"],[0.97,"Ban","BanS","coluzzii","Burkina Faso"],[2.36,"Ban","BanS","coluzzii","Burkina Faso"],[1.39,"Ban","BanS","coluzzii","Burkina Faso"],[1.35,"Ban","BanS","coluzzii","Burkina Faso"],[0.85,"Ban","BanS","coluzzii","Burkina Faso"],[1.37,"Ban","BanS","coluzzii","Burkina Faso"],[0.25,"Ban","BanS","coluzzii","Burkina Faso"],[1.01,"Ban","BanS","coluzzii","Burkina Faso"],[1.35,"Ban","BanS","coluzzii","Burkina Faso"],[0.54,"Ban","BanS","coluzzii","Burkina Faso"],[1.31,"Ban"," ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="c79c2f5a-ca91-4758-bf2d-0da313019965" class="plotly-graph-div" style="height:420px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c79c2f5a-ca91-4758-bf2d-0da313019965")) {                    Plotly.newPlot(                        "c79c2f5a-ca91-4758-bf2d-0da313019965",                        [{"alignmentgroup":"True","boxpoints":"all","customdata":[[0.48,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[1.06,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[0.3,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[0.48,"Ban","BanS","coluzzii","Burkina Faso"],[0.9,"Ban","BanS","coluzzii","Burkina Faso"],[0.5,"Ban","BanS","coluzzii","Burkina Faso"],[1.67,"BanRe","BanS","coluzzii","Burkina Faso"],[1.01,"BanRe","BanS","coluzzii","Burkina Faso"],[1.35,"BanRe","BanS","coluzzii","Burkina Faso"],[0.34,"VK7","Kisumu","coluzzii","Burkina Faso"],[0.85,"VK7","Kisumu","coluzzii","Burkina Faso"],[0.51,"VK7","Kisumu","coluzzii","Burkina Faso"],[1.57,"Cameroon","Ngousso","coluzzii","Cameroon"],[0.88,"Cameroon","Ngousso","coluzzii","Cameroon"],[1.07,"Cameroon","Ngousso","coluzzii","Cameroon"],[4.66,"Chad","Ngousso","coluzzii","Chad"],[0.87,"Chad","Ngousso","coluzzii","Chad"],[1.8,"Chad","Ngousso","coluzzii","Chad"],[6.36,"Niger","Ngousso","coluzzii","Niger"],[0.81,"Niger","Ngousso","coluzzii","Niger"],[1.95,"Niger","Ngousso","coluzzii","Niger"],[3.34,"Nigeria","Ngousso","coluzzii","Nigeria"],[0.95,"Nigeria","Ngousso","coluzzii","Nigeria"],[1.85,"Nigeria","Ngousso","coluzzii","Nigeria"],[0.58,"Agboville","Mali","coluzzii","Cote d'Ivoire"],[1.08,"Agboville","Mali","coluzzii","Cote d'Ivoire"],[0.83,"Agboville","Mali","coluzzii","Cote d'Ivoire"],[0.69,"Agboville","Ngousso","coluzzii","Cote d'Ivoire"],[2.0,"Agboville","Ngousso","coluzzii","Cote d'Ivoire"],[1.39,"Agboville","Ngousso","coluzzii","Cote d'Ivoire"],[0.33,"Dabou","Mali","coluzzii","Cote d'Ivoire"],[0.9,"Dabou","Mali","coluzzii","Cote d'Ivoire"],[1.22,"Dabou","Mali","coluzzii","Cote d'Ivoire"],[0.39,"Dabou","Ngousso","coluzzii","Cote d'Ivoire"],[1.66,"Dabou","Ngousso","coluzzii","Cote d'Ivoire"],[2.03,"Dabou","Ngousso","coluzzii","Cote d'Ivoire"],[0.51,"Tiassale","Mali","coluzzii","Cote d'Ivoire"],[0.92,"Tiassale","Mali","coluzzii","Cote d'Ivoire"],[0.85,"Tiassale","Mali","coluzzii","Cote d'Ivoire"],[0.6,"Tiassale","Ngousso","coluzzii","Cote d'Ivoire"],[1.72,"Tiassale","Ngousso","coluzzii","Cote d'Ivoire"],[1.41,"Tiassale","Ngousso","coluzzii","Cote d'Ivoire"],[0.47,"Bouake_colu_unexp","Ngousso","coluzzii","Cote d'Ivoire"],[1.19,"Bouake_colu_unexp","Ngousso","coluzzii","Cote d'Ivoire"],[1.66,"Bouake_colu_unexp","Ngousso","coluzzii","Cote d'Ivoire"]],"fillcolor":"rgba(255,255,255,0)","hoveron":"points","hovertemplate":"species=%{customdata[3]}<br>log2fold_change=%{x}<br>Label=%{y}<br>fold_change=%{customdata[0]}<br>resistant=%{customdata[1]}<br>susceptible=%{customdata[2]}<br>country=%{customdata[4]}<extra></extra>","legendgroup":"coluzzii","line":{"color":"rgba(255,255,255,0)"},"marker":{"color":"#F8766D"},"name":"coluzzii","offsetgroup":"coluzzii","orientation":"h","pointpos":0,"showlegend":true,"x":[-1.05,0.08,-1.74,-1.07,-0.16,-1.01,0.74,0.01,0.43,-1.56,-0.24,-0.96,0.65,-0.19,0.1,2.22,-0.2,0.85,2.67,-0.31,0.96,1.74,-0.08,0.89,-0.79,0.11,-0.27,-0.54,1.0,0.47,-1.6,-0.16,0.29,-1.36,0.73,1.02,-0.98,-0.12,-0.24,-0.74,0.78,0.5,-1.09,0.25,0.73],"x0":" ","xaxis":"x","y":["AGAP009176","AGAP002809","AGAP001899","AGAP009176","AGAP002809","AGAP001899","AGAP009176","AGAP002809","AGAP001899","AGAP009176","AGAP002809","AGAP001899","AGAP009176","AGAP002809","AGAP001899","AGAP009176","AGAP002809","AGAP001899","AGAP009176","AGAP002809","AGAP001899","AGAP009176","AGAP002809","AGAP001899","AGAP009176","AGAP002809","AGAP001899","AGAP009176","AGAP002809","AGAP001899" ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="304d0097-95de-41aa-addb-32272f55bb7e" class="plotly-graph-div" style="height:2100px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("304d0097-95de-41aa-addb-32272f55bb7e")) {                    Plotly.newPlot(                        "304d0097-95de-41aa-addb-32272f55bb7e",                        [{"alignmentgroup":"True","boxpoints":"all","customdata":[[0.54,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[1.15,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[1.67,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[1.17,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[1.23,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[1.1,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[0.55,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[0.66,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[2.87,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[0.66,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[0.49,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[0.76,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[0.57,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[0.62,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[2.79,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[0.63,"Ban","BanS","coluzzii","Burkina Faso"],[1.84,"Ban","BanS","coluzzii","Burkina Faso"],[0.88,"Ban","BanS","coluzzii","Burkina Faso"],[0.96,"Ban","BanS","coluzzii","Burkina Faso"],[1.05,"Ban","BanS","coluzzii","Burkina Faso"],[1.05,"Ban","BanS","coluzzii","Burkina Faso"],[1.37,"Ban","BanS","coluzzii","Burkina Faso"],[1.07,"Ban","BanS","coluzzii","Burkina Faso"],[1.88,"Ban","BanS","coluzzii","Burkina Faso"],[1.18,"Ban","BanS","coluzzii","Burkina Faso"],[0.62,"Ban","BanS","coluzzii","Burkina Faso"],[1.26,"Ban","BanS","coluzzii","Burkina Faso"],[0.64,"Ban","BanS","coluzzii","Burkina Faso"],[0.75,"Ban","BanS","coluzzii","Burkina Faso"],[1.24,"Ban","BanS","coluzzii","Burkina Faso"],[1.17,"BanRe","BanS","coluzzii","Burkina Faso"],[0.57,"BanRe","BanS","coluzzii","Burkina Faso"],[1.04,"BanRe","BanS","coluzzii","Burkina Faso"],[0.99,"BanRe","BanS","coluzzii","Burkina Faso"],[0.66,"BanRe","BanS","coluzzii","Burkina Faso"],[1.21,"BanRe","BanS","coluzzii","Burkina Faso"],[0.22,"BanRe","BanS","coluzzii","Burkina Faso"],[0.56,"BanRe","BanS","coluzzii","Burkina Faso"],[1.03,"BanRe","BanS","coluzzii","Burkina Faso"],[1.95,"BanRe","BanS","coluzzii","Burkina Faso"],[2.17,"BanRe","BanS","coluzzii","Burkina Faso"],[1.13,"BanRe","BanS","coluzzii","Burkina Faso"],[0.97,"BanRe","BanS","coluzzii","Burkina Faso"],[1.0,"BanRe","BanS","coluzzii","Burkina Faso"],[0.29,"BanRe","BanS","coluzzii","Burkina Faso"],[1.08,"VK7","Kisumu","coluzzii","Burkina Faso"],[0.95,"VK7","Kisumu","coluzzii","Burkina Faso"],[0.52,"VK7","Kisumu","coluzzii","Burkina Faso"],[1.25,"VK7","Kisumu","coluzzii","Burkina Faso"],[0.81,"VK7","Kisumu","coluzzii","Burkina Faso"],[1.1,"VK7","Kisumu","coluzzii","Burkina Faso"],[0.72,"VK7","Kisumu","coluzzii","Burkina Faso"],[1.64,"VK7","Kisumu","coluzzii","Burkina Faso"],[0.77,"VK7","Kisumu","coluzzii","Burkina Faso"],[0.35,"VK7","Kisumu","coluzzii","Burkina Faso"],[0.43,"VK7","Kisumu","coluzzii","Burkina Faso"],[0.69,"VK7","Kisumu","coluzzii","Burkina Faso"],[0.61,"VK7","Kisumu","coluzzii","Burkina Faso"],[1.97,"VK7","Kisumu","coluzzii","Burkina Faso"],[1.82,"VK7","Kisumu","coluzzii","Burkina Faso"],[0.9,"Cameroon","Ngousso","coluzzii","Cameroon"],[1.1,"Cameroon","Ngousso","coluzzii","Cameroon"],[0.46,"Cameroon","Ngousso","coluzzii","Cameroon"],[0.96,"Cameroon","Ngousso","coluzzii","Cameroon"],[0.99,"Cameroon","Ngousso","coluzzii","Cameroon"],[0.7,"Cameroon","Ngousso","coluzzii","Cameroon"],[1.29,"Cameroon","Ngousso","coluzzii","Cameroon"],[0.59,"Cameroon","Ngousso","coluzzii","Cameroon"],[2.2,"Cameroon","Ngousso","coluzzii","Cameroon"],[2.73,"Cameroon","Ngousso ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="aa0f84ee-1ba7-45d5-9a7a-8abc8410ee50" class="plotly-graph-div" style="height:1120px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("aa0f84ee-1ba7-45d5-9a7a-8abc8410ee50")) {                    Plotly.newPlot(                        "aa0f84ee-1ba7-45d5-9a7a-8abc8410ee50",                        [{"alignmentgroup":"True","boxpoints":"all","customdata":[[0.91,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[0.95,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[0.75,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[1.16,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[0.59,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[1.05,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[1.43,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[0.69,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[1.01,"Ban","BanS","coluzzii","Burkina Faso"],[0.87,"Ban","BanS","coluzzii","Burkina Faso"],[0.82,"Ban","BanS","coluzzii","Burkina Faso"],[0.99,"Ban","BanS","coluzzii","Burkina Faso"],[0.58,"Ban","BanS","coluzzii","Burkina Faso"],[1.08,"Ban","BanS","coluzzii","Burkina Faso"],[1.06,"Ban","BanS","coluzzii","Burkina Faso"],[0.76,"Ban","BanS","coluzzii","Burkina Faso"],[0.69,"BanRe","BanS","coluzzii","Burkina Faso"],[0.67,"BanRe","BanS","coluzzii","Burkina Faso"],[1.37,"BanRe","BanS","coluzzii","Burkina Faso"],[1.01,"BanRe","BanS","coluzzii","Burkina Faso"],[1.4,"BanRe","BanS","coluzzii","Burkina Faso"],[1.35,"BanRe","BanS","coluzzii","Burkina Faso"],[1.0,"BanRe","BanS","coluzzii","Burkina Faso"],[0.7,"BanRe","BanS","coluzzii","Burkina Faso"],[0.28,"VK7","Kisumu","coluzzii","Burkina Faso"],[0.93,"VK7","Kisumu","coluzzii","Burkina Faso"],[0.52,"VK7","Kisumu","coluzzii","Burkina Faso"],[0.48,"VK7","Kisumu","coluzzii","Burkina Faso"],[0.76,"VK7","Kisumu","coluzzii","Burkina Faso"],[1.06,"VK7","Kisumu","coluzzii","Burkina Faso"],[0.94,"VK7","Kisumu","coluzzii","Burkina Faso"],[0.97,"VK7","Kisumu","coluzzii","Burkina Faso"],[0.68,"Cameroon","Ngousso","coluzzii","Cameroon"],[1.33,"Cameroon","Ngousso","coluzzii","Cameroon"],[0.91,"Cameroon","Ngousso","coluzzii","Cameroon"],[1.13,"Cameroon","Ngousso","coluzzii","Cameroon"],[1.26,"Cameroon","Ngousso","coluzzii","Cameroon"],[0.43,"Cameroon","Ngousso","coluzzii","Cameroon"],[1.87,"Cameroon","Ngousso","coluzzii","Cameroon"],[1.41,"Cameroon","Ngousso","coluzzii","Cameroon"],[0.43,"Chad","Ngousso","coluzzii","Chad"],[1.47,"Chad","Ngousso","coluzzii","Chad"],[1.78,"Chad","Ngousso","coluzzii","Chad"],[0.84,"Chad","Ngousso","coluzzii","Chad"],[2.5,"Chad","Ngousso","coluzzii","Chad"],[0.31,"Chad","Ngousso","coluzzii","Chad"],[1.37,"Chad","Ngousso","coluzzii","Chad"],[1.23,"Chad","Ngousso","coluzzii","Chad"],[0.53,"Niger","Ngousso","coluzzii","Niger"],[2.3,"Niger","Ngousso","coluzzii","Niger"],[2.89,"Niger","Ngousso","coluzzii","Niger"],[1.34,"Niger","Ngousso","coluzzii","Niger"],[4.08,"Niger","Ngousso","coluzzii","Niger"],[0.49,"Niger","Ngousso","coluzzii","Niger"],[1.37,"Niger","Ngousso","coluzzii","Niger"],[1.36,"Niger","Ngousso","coluzzii","Niger"],[0.66,"Nigeria","Ngousso","coluzzii","Nigeria"],[2.31,"Nigeria","Ngousso","coluzzii","Nigeria"],[1.62,"Nigeria","Ngousso","coluzzii","Nigeria"],[1.14,"Nigeria","Ngousso","coluzzii","Nigeria"],[3.41,"Nigeria","Ngousso","coluzzii","Nigeria"],[0.38,"Nigeria","Ngousso","coluzzii","Nigeria"],[1.78,"Nigeria","Ngousso","coluzzii","Nigeria"],[1.68,"Nigeria","Ngousso","coluzzii","Nigeria"],[2.04,"Agboville","Mali","coluzzii","Cote d'Ivoire"],[0.77,"Agboville","Mali","coluzzii","Cote d'Ivoire"],[0.76,"Agboville","Mali","coluzzii","Cote d'Ivoire"],[0.68,"Agboville","Mali","coluzzii","Cote d'Ivoire"],[1.09,"Agboville","Mali","coluzzii","Cote d'Ivoire"],[1.41,"Agboville","Mali","coluzzii","Cote d'Ivoire"],[0.59,"Agboville","Mali","coluzzii","Cote d'Ivoi ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="f044d17b-7f83-41b9-af8e-cda3e1d2c939" class="plotly-graph-div" style="height:1820px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f044d17b-7f83-41b9-af8e-cda3e1d2c939")) {                    Plotly.newPlot(                        "f044d17b-7f83-41b9-af8e-cda3e1d2c939",                        [{"alignmentgroup":"True","boxpoints":"all","customdata":[[2.73,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[1.6,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[0.6,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[1.39,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[0.58,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[1.42,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[1.64,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[1.66,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[0.68,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[2.33,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[1.61,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[1.01,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[3.07,"Tiefora","Ngousso","coluzzii","Burkina Faso"],[0.11,"Ban","BanS","coluzzii","Burkina Faso"],[0.85,"Ban","BanS","coluzzii","Burkina Faso"],[0.84,"Ban","BanS","coluzzii","Burkina Faso"],[0.95,"Ban","BanS","coluzzii","Burkina Faso"],[0.62,"Ban","BanS","coluzzii","Burkina Faso"],[1.01,"Ban","BanS","coluzzii","Burkina Faso"],[0.49,"Ban","BanS","coluzzii","Burkina Faso"],[1.31,"Ban","BanS","coluzzii","Burkina Faso"],[0.75,"Ban","BanS","coluzzii","Burkina Faso"],[0.91,"Ban","BanS","coluzzii","Burkina Faso"],[1.17,"Ban","BanS","coluzzii","Burkina Faso"],[0.9,"Ban","BanS","coluzzii","Burkina Faso"],[2.03,"Ban","BanS","coluzzii","Burkina Faso"],[0.41,"BanRe","BanS","coluzzii","Burkina Faso"],[0.58,"BanRe","BanS","coluzzii","Burkina Faso"],[0.96,"BanRe","BanS","coluzzii","Burkina Faso"],[0.72,"BanRe","BanS","coluzzii","Burkina Faso"],[0.66,"BanRe","BanS","coluzzii","Burkina Faso"],[0.84,"BanRe","BanS","coluzzii","Burkina Faso"],[1.04,"BanRe","BanS","coluzzii","Burkina Faso"],[0.86,"BanRe","BanS","coluzzii","Burkina Faso"],[0.83,"BanRe","BanS","coluzzii","Burkina Faso"],[0.6,"BanRe","BanS","coluzzii","Burkina Faso"],[0.71,"BanRe","BanS","coluzzii","Burkina Faso"],[0.97,"BanRe","BanS","coluzzii","Burkina Faso"],[0.92,"BanRe","BanS","coluzzii","Burkina Faso"],[2.03,"VK7","Kisumu","coluzzii","Burkina Faso"],[0.37,"VK7","Kisumu","coluzzii","Burkina Faso"],[0.67,"VK7","Kisumu","coluzzii","Burkina Faso"],[1.39,"VK7","Kisumu","coluzzii","Burkina Faso"],[0.84,"VK7","Kisumu","coluzzii","Burkina Faso"],[0.85,"VK7","Kisumu","coluzzii","Burkina Faso"],[0.99,"VK7","Kisumu","coluzzii","Burkina Faso"],[1.13,"VK7","Kisumu","coluzzii","Burkina Faso"],[0.39,"VK7","Kisumu","coluzzii","Burkina Faso"],[1.82,"VK7","Kisumu","coluzzii","Burkina Faso"],[1.14,"VK7","Kisumu","coluzzii","Burkina Faso"],[1.35,"VK7","Kisumu","coluzzii","Burkina Faso"],[1.34,"VK7","Kisumu","coluzzii","Burkina Faso"],[0.18,"Cameroon","Ngousso","coluzzii","Cameroon"],[0.99,"Cameroon","Ngousso","coluzzii","Cameroon"],[1.2,"Cameroon","Ngousso","coluzzii","Cameroon"],[0.61,"Cameroon","Ngousso","coluzzii","Cameroon"],[1.25,"Cameroon","Ngousso","coluzzii","Cameroon"],[0.63,"Cameroon","Ngousso","coluzzii","Cameroon"],[1.27,"Cameroon","Ngousso","coluzzii","Cameroon"],[0.82,"Cameroon","Ngousso","coluzzii","Cameroon"],[1.26,"Cameroon","Ngousso","coluzzii","Cameroon"],[1.16,"Cameroon","Ngousso","coluzzii","Cameroon"],[0.93,"Cameroon","Ngousso","coluzzii","Cameroon"],[1.69,"Cameroon","Ngousso","coluzzii","Cameroon"],[5.78,"Cameroon","Ngousso","coluzzii","Cameroon"],[0.09,"Chad","Ngousso","coluzzii","Chad"],[0.84,"Chad","Ngousso","coluzzii","Chad"],[1.65,"Chad","Ngousso","coluzzii","Chad"],[0.84,"Chad","Ngousso","coluzzii","Chad"],[1.01,"Chad","Ngousso","coluzzii","Chad"],[0. ...
