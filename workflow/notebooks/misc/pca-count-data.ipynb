# %% [markdown]
# <a href="https://colab.research.google.com/github/sanjaynagi/Ano-expressIR/blob/main/workflow/notebooks/misc/pca-count-data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import plotly.express as px

# %% [markdown]
# # Principal components analysis

# %%
### TODO - fix subsetting metadata when full dataset is not used

# %%
def pca(analysis, x="PC1", y="PC2"):
  from sklearn.decomposition import PCA

  sample_metadata = pd.read_csv("https://raw.githubusercontent.com/sanjaynagi/ano-expressir/main/config/sample_metadata.tsv", sep="\t").rename(columns={'colData':'sampleID'})
  count_data = pd.read_csv(f"https://raw.githubusercontent.com/sanjaynagi/ano-expressir/main/results/log2counts.{analysis}.tsv", sep="\t").set_index("GeneID")

  pca = PCA(n_components=6)
  principalComponents = pca.fit_transform(count_data.T)
  pc = pd.DataFrame(data = principalComponents, columns = ['PC1', 'PC2', 'PC3', 'PC4', 'PC5', 'PC6'])
  pca_df = pd.concat([sample_metadata, pc], axis=1)
  fig = px.scatter(data_frame=pca_df, x=x, y=y, color='species', hover_data = ['condition', 'resistance'], template="ggplot2", width=800, height=600)

  pc_df = pd.DataFrame({'PC':['PC1', 'PC2', 'PC3', 'PC4', 'PC5', 'PC6'], 
              'explained_variance':pca.explained_variance_ratio_})

  var_fig=px.bar(pc_df, x='PC', y='explained_variance', width=800, height=400)  
  var_fig.show()
  return(fig)

# %% [markdown]
# ### PC1 V PC2

# %%
### plot interactive PCA data 
pca(analysis='gamb_colu_arab_fun')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ### PC3 vc PC4

# %%
pca(analysis='gamb_colu_arab_fun', x='PC3', y="PC4")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
